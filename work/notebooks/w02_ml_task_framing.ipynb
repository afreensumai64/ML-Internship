# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/afreensumai64/ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# **Task type: Ranking / Scoring**
#
# My chosen lane is Refresh / Content Opportunity Scoring. I frame this as a ranking and scoring problem because the goal is not simply to classify pages as good or bad. The goal is to assign pages an opportunity or review-priority score and rank them so that a content or SEO team can decide which pages to inspect first. The output should support prioritization under limited review capacity, with reason codes that explain why a page received a high score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or proxy
#
# The ideal target would be whether a page is genuinely underperforming relative to its potential and would benefit from an intervention, but this outcome is not directly observed in the starter data.
#
# For the starter experiment, I will use **`is_declining_label`**, defined as `trend_direction == "down"`, as a proxy label for decline risk. This is measurable in the current dataset and gives the model a concrete outcome to learn from.
#
# I will treat this as a proxy rather than a ground-truth label. A page being classified as declining does not prove that refreshing it will improve performance. A stronger future version of the project could define a future-window outcome, such as decline or recovery over a later period, while keeping the feature window separate to avoid leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success metric
#
# **Primary metric: Precision@50.**
#
# Precision@50 measures the fraction of the top 50 pages in the ranked review queue that have the chosen proxy label. This matches the real decision because a content or SEO team has limited capacity and may only review a small number of pages first.
#
# A higher Precision@50 means that more of the pages prioritized for review correspond to the outcome we are trying to identify. I will treat this metric as evaluation of the starter decline-detection proxy, not as proof that the pages will benefit from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/afreensumai64/ML-Internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Shape:", df.shape)

display(
    df[
        [
            "content_id",
            "impressions_90d",
            "clicks_90d",
            "sessions_90d",
            "content_age_days",
            "trend_direction"
        ]
    ].head()
)
# Out:
# Shape: (30000, 44)
#              content_id  impressions_90d  clicks_90d  sessions_90d  \
# 0  content_304f48230142             3803          29            17
# 1  content_a1fb4e703a9e            15320           7             9
# 2  content_9aa793d4d895            12581          11            11
# 3  content_331d6c4de07b            11751          58            78
# 4  content_d99b7a2d90ca            19140          24           145
#
#    content_age_days trend_direction
# 0               187            down
# 1               445            down
# 2               141            down
# 3               463          stable
# 4               263            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
#
# Before you submit, confirm each line honestly:
#
# - ☑ Every section above is filled — markdown thinking AND the code that backs it
# - ☑ The notebook runs top to bottom with no errors
# - ☑ No client names, URLs, or private queries anywhere
# - ☑ My claims use careful words: observed, measured, directional, decision-support
# - ☑ Committed to my repo under `work/notebooks/`
